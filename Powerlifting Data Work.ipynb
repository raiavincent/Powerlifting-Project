# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # To Do:
# Clean up the cells to avoid duplication and redundancy, plus a clearer presentation.
# Find a way to see how the changes in wilks seem to go as the lifter does more meets.

# %%
data = pd.read_csv(
    'Data/openpowerlifting-2020-06-20.csv')

# %%
opdata = pd.read_csv(
    'Data/openpowerlifting-2020-06-20.csv')

# %%
opdata.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'AgeClass',
#        'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
#        'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Best3BenchKg',
#        'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
#        'Best3DeadliftKg', 'TotalKg', 'Place', 'Dots', 'Wilks', 'Glossbrenner',
#        'Goodlift', 'Tested', 'Country', 'Federation', 'ParentFederation',
#        'Date', 'MeetCountry', 'MeetState', 'MeetTown', 'MeetName'],
#       dtype='object')

# %%
# there are a lot of columns that I am not looking to use at the moment so I will drop a bunch
opdata.drop(columns = ['Age','AgeClass','BirthYearClass','Squat1Kg','Squat2Kg','Squat3Kg','Squat4Kg','Bench1Kg','Bench2Kg',
            'Bench3Kg','Bench4Kg','Deadlift1Kg','Deadlift2Kg','Deadlift3Kg','Deadlift4Kg','Place','Date','MeetCountry',
            'MeetState', 'MeetTown'], inplace = True)

# %%
opdata.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Division', 'BodyweightKg',
#        'WeightClassKg', 'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg',
#        'TotalKg', 'Dots', 'Wilks', 'Glossbrenner', 'Goodlift', 'Tested',
#        'Country', 'Federation', 'ParentFederation', 'MeetName'],
#       dtype='object')

# %%
# save so you do not have to clean again
# opdata.to_csv('./data/opdatacorrect.csv', encoding='utf-8', index = False)
# commenting out as I do not have to make this 5mil times every time I run the notebook

# %%
opdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1979433 entries, 0 to 1979432
# Data columns (total 20 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Name              object
#  1   Sex               object
#  2   Event             object
#  3   Equipment         object
#  4   Division          object
#  5   BodyweightKg      float64
#  6   WeightClassKg     object
#  7   Best3SquatKg      float64
#  8   Best3BenchKg      float64
#  9   Best3DeadliftKg   float64
#  10  TotalKg           float64
#  11  Dots              float64
#  12  Wilks             float64
#  13  Glossbrenner      float64
#  14  Goodlift          float64
#  15  Tested            object
#  16  Country           object
#  17  Federation        object
#  18  ParentFederation  object
#  19  MeetName          object
# dtypes: float64(9), object(11)
# memory usage: 302.0+ MB

# %%
opdata.head()
# Out:
#                  Name Sex Event   Equipment       Division  BodyweightKg  \
# 0      Tucker Sanders   M     B  Single-ply     Teen 14-15          52.0
# 1       Xander Womack   M     B  Single-ply     Teen 14-15         100.0
# 2  Michael Womack III   M     B  Single-ply     Teen 16-17          67.5
# 3      Logan McCurley   M     B  Single-ply     Teen 16-17          75.0
# 4       Emily Jondron   F     B  Single-ply  Juniors 20-25          90.0
#
#   WeightClassKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg    Dots  \
# 0            52           NaN          85.0              NaN     85.0   81.41
# 1           100           NaN         162.5              NaN    162.5  100.02
# 2          67.5           NaN         110.0              NaN    110.0   84.78
# 3            75           NaN         117.5              NaN    117.5   84.30
# 4            90           NaN         160.0              NaN    160.0  142.64
#
# ...

# %%
opdata.tail()
# Out:
#                    Name Sex Event Equipment Division  BodyweightKg  \
# 1979428     Zaden Jones   M   SBD     Wraps    youth         86.18
# 1979429     Pablo Nunez   M   SBD       Raw      int         80.29
# 1979430      Jim Harper   M    BD       Raw       mp         96.16
# 1979431      Devin Deer   M    BD       Raw       so        137.89
# 1979432  Shawn Avery Jr   M     B       Raw    youth         50.80
#
#         WeightClassKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg  \
# 1979428            90          70.0          42.5             80.0    192.5
# 1979429          82.5         202.5         117.5            300.0    620.0
# 1979430           100           NaN         115.0            187.5    302.5
# 1979431           140           NaN          57.5            100.0    157.5
# 1979432            52           NaN          30.0              NaN     30.0
#
#            Dots   Wilks  Glossbrenner  Goodlift Tested Country Federation  \
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format
opdata.describe()
# Out:
#        BodyweightKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg    TotalKg  \
# count    1952366.00    1374012.00    1751513.00       1464421.00 1832822.00
# mean          84.11        175.05        118.19           189.10     388.82
# std           22.88         69.48         54.57            62.38     204.11
# min           15.10       -477.50       -522.50          -410.00       1.00
# 25%           67.00        122.50         75.00           140.00     217.72
# 50%           81.92        170.00        115.00           188.24     369.68
# 75%           99.00        219.99        152.50           235.00     540.00
# max          260.20        580.00        488.50           460.40    1407.50
#
#             Dots      Wilks  Glossbrenner   Goodlift
# count 1815550.00 1815550.00    1815550.00 1673707.00
# mean      283.48     282.47        266.23      63.77
# std       126.67     126.22        120.21      16.20
# min         0.68       0.67          0.64       0.50
# ...

# %%
opdata.loc[opdata['BodyweightKg'] > 260.00000]
# Out:
#                      Name Sex Event Equipment   Division  BodyweightKg  \
# 1150308  James Simmons #1   M     B       Raw  M_OR_AAPF        260.20
#
#         WeightClassKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg  \
# 1150308          140+           nan        195.00              nan   195.00
#
#          Dots  Wilks  Glossbrenner  Goodlift Tested Country Federation  \
# 1150308 96.65 103.64         91.78     64.88    Yes     NaN        APF
#
#         ParentFederation     MeetName
# 1150308              WPC  Summer Bash

# %%
opdata['Equipment'].value_counts(ascending=False)
# Out:
# Single-ply    1042117
# Raw            701877
# Wraps          134624
# Multi-ply      100775
# Straps             40
# Name: Equipment, dtype: int64

# %%
opdata.loc[opdata['Name'] == 'Michael Sin']
# Out:
#                Name Sex Event Equipment               Division  BodyweightKg  \
# 399778  Michael Sin   M   SBD     Wraps  Amateur Juniors 20-23         88.09
# 400241  Michael Sin   M   SBD     Wraps  Amateur Juniors 20-23         89.72
#
#        WeightClassKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg  \
# 399778            90        199.58        131.54           258.55   589.67
# 400241            90        201.85        131.54           272.16   605.55
#
#          Dots  Wilks  Glossbrenner  Goodlift Tested Country Federation  \
# 399778 385.48 380.66        365.17     79.23    Yes     NaN        RPS
# 400241 392.17 387.19        371.14     80.63    Yes     NaN        RPS
#
#        ParentFederation             MeetName
# 399778              NaN             Dominion
# 400241              NaN  Autumn Apocalypse 8

# %%
opdata.loc[opdata['Name'] == 'Vincent Raia']
# Out:
#                  Name Sex Event Equipment               Division  \
# 399776   Vincent Raia   M   SBD       Raw  Amateur Juniors 20-23
# 400239   Vincent Raia   M   SBD       Raw  Amateur Juniors 20-23
# 1237888  Vincent Raia   M   SBD       Raw                   Open
#
#          BodyweightKg WeightClassKg  Best3SquatKg  Best3BenchKg  \
# 399776          85.09            90        188.24        113.40
# 400239          84.10            90        199.58        124.74
# 1237888         86.00            90        205.00        132.50
#
#          Best3DeadliftKg  TotalKg   Dots  Wilks  Glossbrenner  Goodlift  \
# 399776            206.38   508.02 338.28 334.25        321.16     69.45
# 400239            226.80   551.11 369.33 365.04        350.93     75.78
# 1237888           220.00   557.50 369.10 364.62        350.17     75.81
#
#         Tested Country Federation ParentFederation               MeetName
# 399776     Yes     USA        RPS              NaN               Dominion
# ...

# %%
opdata['Bodyweight'] = opdata['BodyweightKg'] * 2.20462

# %%
opdata['Bodyweight']
# Out:
# 0         114.64
# 1         220.46
# 2         148.81
# 3         165.35
# 4         198.42
#            ...
# 1979428   189.99
# 1979429   177.01
# 1979430   212.00
# 1979431   304.00
# 1979432   111.99
# Name: Bodyweight, Length: 1979433, dtype: float64

# %%
opdata.loc[opdata['Name'] == 'Vincent Raia']
# Out:
#                  Name Sex Event Equipment               Division  \
# 399776   Vincent Raia   M   SBD       Raw  Amateur Juniors 20-23
# 400239   Vincent Raia   M   SBD       Raw  Amateur Juniors 20-23
# 1237888  Vincent Raia   M   SBD       Raw                   Open
#
#          BodyweightKg WeightClassKg  Best3SquatKg  Best3BenchKg  \
# 399776          85.09            90        188.24        113.40
# 400239          84.10            90        199.58        124.74
# 1237888         86.00            90        205.00        132.50
#
#          Best3DeadliftKg  ...   Dots  Wilks  Glossbrenner  Goodlift  Tested  \
# 399776            206.38  ... 338.28 334.25        321.16     69.45     Yes
# 400239            226.80  ... 369.33 365.04        350.93     75.78     Yes
# 1237888           220.00  ... 369.10 364.62        350.17     75.81     NaN
#
#         Country Federation ParentFederation               MeetName Bodyweight
# ...

# %%
opdata.drop(columns=['BodyweightKg'])
# Out:
#                        Name Sex Event   Equipment       Division  \
# 0            Tucker Sanders   M     B  Single-ply     Teen 14-15
# 1             Xander Womack   M     B  Single-ply     Teen 14-15
# 2        Michael Womack III   M     B  Single-ply     Teen 16-17
# 3            Logan McCurley   M     B  Single-ply     Teen 16-17
# 4             Emily Jondron   F     B  Single-ply  Juniors 20-25
# ...                     ...  ..   ...         ...            ...
# 1979428         Zaden Jones   M   SBD       Wraps          youth
# 1979429         Pablo Nunez   M   SBD         Raw            int
# 1979430          Jim Harper   M    BD         Raw             mp
# 1979431          Devin Deer   M    BD         Raw             so
# 1979432      Shawn Avery Jr   M     B         Raw          youth
#
#         WeightClassKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg  \
# 0                  52           nan         85.00              nan    85.00
# ...

# %%
opdata = opdata[['Name', 'Sex', 'Event', 'Bodyweight', 'Equipment', 'Division',
       'WeightClassKg', 'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg',
       'TotalKg', 'Dots', 'Wilks', 'Glossbrenner', 'Goodlift', 'Tested',
       'Country', 'Federation', 'ParentFederation', 'MeetName',]]

# %%
opdata.loc[opdata['Name'] == 'Vincent Raia']
# Out:
#                  Name Sex Event  Bodyweight Equipment               Division  \
# 399776   Vincent Raia   M   SBD      187.59       Raw  Amateur Juniors 20-23
# 400239   Vincent Raia   M   SBD      185.41       Raw  Amateur Juniors 20-23
# 1237888  Vincent Raia   M   SBD      189.60       Raw                   Open
#
#         WeightClassKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg  \
# 399776             90        188.24        113.40           206.38   508.02
# 400239             90        199.58        124.74           226.80   551.11
# 1237888            90        205.00        132.50           220.00   557.50
#
#           Dots  Wilks  Glossbrenner  Goodlift Tested Country Federation  \
# 399776  338.28 334.25        321.16     69.45    Yes     USA        RPS
# 400239  369.33 365.04        350.93     75.78    Yes     USA        RPS
# 1237888 369.10 364.62        350.17     75.81    NaN     USA       USPA
#
#         ParentFederation               MeetName
# ...

# %%
opdata['Best Squat'] = opdata['Best3SquatKg'] * 2.20462
opdata['Best Squat']
# Out:
# 0            nan
# 1            nan
# 2            nan
# 3            nan
# 4            nan
#            ...
# 1979428   154.32
# 1979429   446.44
# 1979430      nan
# 1979431      nan
# 1979432      nan
# Name: Best Squat, Length: 1979433, dtype: float64

# %%
opdata['Best Bench Press'] = opdata['Best3BenchKg'] * 2.20462
opdata['Best Bench Press']
# Out:
# 0         187.39
# 1         358.25
# 2         242.51
# 3         259.04
# 4         352.74
#            ...
# 1979428    93.70
# 1979429   259.04
# 1979430   253.53
# 1979431   126.77
# 1979432    66.14
# Name: Best Bench Press, Length: 1979433, dtype: float64

# %%
opdata['Best Deadlift'] = opdata['Best3DeadliftKg'] * 2.20462
opdata['Best Deadlift']
# Out:
# 0            nan
# 1            nan
# 2            nan
# 3            nan
# 4            nan
#            ...
# 1979428   176.37
# 1979429   661.39
# 1979430   413.37
# 1979431   220.46
# 1979432      nan
# Name: Best Deadlift, Length: 1979433, dtype: float64

# %%
opdata['Total'] = opdata['TotalKg'] * 2.20462
opdata['Total']
# Out:
# 0          187.39
# 1          358.25
# 2          242.51
# 3          259.04
# 4          352.74
#             ...
# 1979428    424.39
# 1979429   1366.86
# 1979430    666.90
# 1979431    347.23
# 1979432     66.14
# Name: Total, Length: 1979433, dtype: float64

# %%
opdata = opdata[['Name', 'Sex', 'Event', 'Bodyweight', 'Equipment', 'Division',
       'WeightClassKg', 'Best Squat', 'Best Bench Press', 'Best Deadlift',
       'Total', 'Dots', 'Wilks', 'Glossbrenner', 'Goodlift', 'Tested',
       'Country', 'Federation', 'ParentFederation', 'MeetName',]]

# %%
opdata
# Out:
#                        Name Sex Event  Bodyweight   Equipment       Division  \
# 0            Tucker Sanders   M     B      114.64  Single-ply     Teen 14-15
# 1             Xander Womack   M     B      220.46  Single-ply     Teen 14-15
# 2        Michael Womack III   M     B      148.81  Single-ply     Teen 16-17
# 3            Logan McCurley   M     B      165.35  Single-ply     Teen 16-17
# 4             Emily Jondron   F     B      198.42  Single-ply  Juniors 20-25
# ...                     ...  ..   ...         ...         ...            ...
# 1979428         Zaden Jones   M   SBD      189.99       Wraps          youth
# 1979429         Pablo Nunez   M   SBD      177.01         Raw            int
# 1979430          Jim Harper   M    BD      212.00         Raw             mp
# 1979431          Devin Deer   M    BD      304.00         Raw             so
# 1979432      Shawn Avery Jr   M     B      111.99         Raw          youth
#
# ...

# %%
opdata.drop(columns = ['Division','Tested','ParentFederation'], inplace = True)

# %%
opdata
# Out:
#                        Name Sex Event  Bodyweight   Equipment WeightClassKg  \
# 0            Tucker Sanders   M     B      114.64  Single-ply            52
# 1             Xander Womack   M     B      220.46  Single-ply           100
# 2        Michael Womack III   M     B      148.81  Single-ply          67.5
# 3            Logan McCurley   M     B      165.35  Single-ply            75
# 4             Emily Jondron   F     B      198.42  Single-ply            90
# ...                     ...  ..   ...         ...         ...           ...
# 1979428         Zaden Jones   M   SBD      189.99       Wraps            90
# 1979429         Pablo Nunez   M   SBD      177.01         Raw          82.5
# 1979430          Jim Harper   M    BD      212.00         Raw           100
# 1979431          Devin Deer   M    BD      304.00         Raw           140
# 1979432      Shawn Avery Jr   M     B      111.99         Raw            52
#
# ...

# %%
opdata = opdata.dropna()

# %%
opdata
# Out:
#                      Name Sex Event  Bodyweight Equipment WeightClassKg  \
# 10         Justin Johnson   M   SBD      148.81     Wraps          67.5
# 14       Michael Schaffer   M   SBD      198.42     Wraps            90
# 17             Sam Cox #2   M   SBD      242.51     Wraps           110
# 19             Adam Vediz   M   SBD      242.51     Wraps           110
# 22             Tim Greeve   M   SBD      275.58     Wraps           125
# ...                   ...  ..   ...         ...       ...           ...
# 1979425     Travis Reiner   M   SBD      208.60     Wraps           100
# 1979426     David Palumbo   M   SBD      227.01     Wraps           110
# 1979427    David Ross III   M   SBD      164.00     Wraps            75
# 1979428       Zaden Jones   M   SBD      189.99     Wraps            90
# 1979429       Pablo Nunez   M   SBD      177.01       Raw          82.5
#
#          Best Squat  Best Bench Press  Best Deadlift   Total   Dots  Wilks  \
# ...

# %%
opdata = opdata[opdata.Equipment != 'Single-ply']

# %%
opdata = opdata[opdata.Equipment != 'Multi-ply']

# %%
opdata = opdata[opdata.Equipment != 'Straps']

# %%
opdata
# Out:
#                      Name Sex Event  Bodyweight Equipment WeightClassKg  \
# 10         Justin Johnson   M   SBD      148.81     Wraps          67.5
# 14       Michael Schaffer   M   SBD      198.42     Wraps            90
# 17             Sam Cox #2   M   SBD      242.51     Wraps           110
# 19             Adam Vediz   M   SBD      242.51     Wraps           110
# 22             Tim Greeve   M   SBD      275.58     Wraps           125
# ...                   ...  ..   ...         ...       ...           ...
# 1979425     Travis Reiner   M   SBD      208.60     Wraps           100
# 1979426     David Palumbo   M   SBD      227.01     Wraps           110
# 1979427    David Ross III   M   SBD      164.00     Wraps            75
# 1979428       Zaden Jones   M   SBD      189.99     Wraps            90
# 1979429       Pablo Nunez   M   SBD      177.01       Raw          82.5
#
#          Best Squat  Best Bench Press  Best Deadlift   Total   Dots  Wilks  \
# ...

# %%
opdata['Equipment'].value_counts(ascending=False)
# Out:
# Raw      256529
# Wraps     82035
# Name: Equipment, dtype: int64

# %%
opdata['Name'].value_counts(ascending=False)
# Out:
# Magomedamin Israpilov    94
# Ellen Stein              49
# Cardell Oliver           45
# Charlie Chester          45
# Christian Kearney        44
#                          ..
# Alix Potts                1
# Jacob Becker              1
# Will Stueve               1
# Zachary Lemke             1
# Jenny Syner               1
# Name: Name, Length: 114666, dtype: int64

# %%
opdata['Event'].value_counts(ascending=False)
# Out:
# SBD    338564
# Name: Event, dtype: int64

# %%
# save as this is pretty much how we need it
opdata.to_csv('./data/opdataSBD.csv', encoding='utf-8', index = False)

# %%
opdata['Wilks'].std()
# Out:
# 70.61165622062566

# %%
sns.regplot(x="Bodyweight", y="Wilks", data=opdata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-03ad47a45a9d> in <module>
# ----> 1 sns.regplot(x="Bodyweight", y="Wilks", data=opdata, figsize=(14,14))
#
# TypeError: regplot() got an unexpected keyword argument 'figsize'
